# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Note: There are 4 DLC packs that will not be considered for this study. The Last Breath, Left Behind, and A Lullaby for the Dark are free content and Chucky, as of the Data Hand-In, is not currently available. All data is from Steam, as it is the only reliable source for plaayer feedback.

# %%
ces = pd.read_csv(r'C:\Users\sonik\Downloads\Data_Collection_results.csv')

# %% [markdown]
# Notable Qualities/Criteria:
#
# License: Are these characters from outside sources (Non-licensed characters cannot be purchased with in-game currency)
#
# Characters: Number of characters that come with each pack
#
# Reception: Public opinion based on reviews.

# %%
ces
# Out:
#     Unnamed: 0                  Pack name Licensed?    Price  Characters   \
# 0            0                  Halloween       Yes   $6.99             2
# 1            1           Of Flesh and Mud        No   $6.99             2
# 2            2           Spark of Madness        No   $6.99             2
# 3            3                Leatherface       Yes   $4.99             1
# 4            4  A Nightmare on Elm Street       Yes   $6.99             2
# 5            5                        Saw       Yes   $6.99             2
# 6            6               Curtain Call        No   $6.99             2
# 7            7        Shattered Bloodline        No   $6.99             2
# 8            8          Darkness Among Us        No   $6.99             2
# 9            9     Demise of the Faithful        No   $6.99             2
# 10          10           Ash vs Evil Dead       Yes   $4.99             1
# 11          11                 Ghost Face       Yes   $4.99             1
# ...
