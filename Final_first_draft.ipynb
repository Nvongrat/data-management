# %% [markdown]
# Noah Vongratana
#
#
# This is an analysis of Dead by Daylight's downloadable content to see if there is any one factor that makes specific content packs more popular than others. In doing this, I wish to to understand how the game has evolved over its 7-year lifespan, but also determine if there is a direction that the game should go in the future. I am doing this out of love for this game, considering the only people who have supposedly done this before are the game's developers, and their results are unknown.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from scipy import stats

# %% [markdown]
# Note: There are 4 DLC packs that will not be considered for this study. The Last Breath, Left Behind, and A Lullaby for the Dark are free content and Chucky, as of the collection of data, is not currently available. All data is from Steam, as it is the only reliable source for player feedback.

# %%
ces = pd.read_csv(r'C:\Users\sonik\Downloads\Data_Collection_results.csv')

# %% [markdown]
# Notable Qualities:
#
# License: Are these characters from outside sources (Non-licensed characters cannot be purchased with in-game currency)
#
# Characters: Number of characters that come with each pack
#
# Reception: Public opinion based on reviews. (Notable Comments are based on reviews)
#
#
# Terminology Note: Perks = equipable skills for respective characters
#
# Final note: Many DLCs listed technically involve new maps, but maps will not be considered for this analysis

# %%
ces
# Out:
#     Release Order                  Pack name Licensed?  Characters  \
# 0               1                  Halloween       Yes           2
# 1               2           Of Flesh and Mud        No           2
# 2               3           Spark of Madness        No           2
# 3               4                Leatherface       Yes           1
# 4               5  A Nightmare on Elm Street       Yes           2
# 5               6                        Saw       Yes           2
# 6               7               Curtain Call        No           2
# 7               8        Shattered Bloodline        No           2
# 8               9          Darkness Among Us        No           2
# 9              10     Demise of the Faithful        No           2
# 10             11           Ash vs Evil Dead       Yes           1
# 11             12                 Ghost Face       Yes           1
# 12             13            Stranger Things       Yes           3
# 13             14              Cursed Legacy        No           2
# 14             15             Chains of Hate        No           2
# 15             16                Silent Hill       Yes           2
# 16             17             Descend Beyond        No           2
# 17             18           A Binding of Kin        No           2
# 18             19                   All-Kill        No           2
# 19             20              Resident Evil       Yes           3
# 20             21                 Hellraiser       Yes           1
# 21             22          Hour of the Witch        No           1
# 22             23       Portrait of a Murder        No           2
# 23             24              Sadako Rising       Yes           2
# 24             25             Roots of Dread        No           2
# 25             26   Resident Evil: PROJECT W       Yes           3
# 26             27              Forged in Fog        No           2
# 27             28           Tools of Torment        No           3
# 28             29           End Transmission        No           2
# 29             30               Nicolas Cage       Yes           1
# 30             31                      Alien       Yes           2
#
#                             Killer                       Survivor(s)  \
# 0        Michael Myers (The Shape)                     Laurie Strode
# 1                          The Hag                      Ace Visconti
# 2                       The Doctor                          Feng Min
# 3       Leatherface (The Cannibal)                               NaN
# 4   Freddy Kreuger (The Nightmare)                     Quentin Smith
# 5                          The Pig              Detective David Tapp
# 6                        The Clown                       Kate Denson
# 7                       The Spirit                      Adam Francis
# 8                       The Legion                     Jeff Johansen
# 9                       The Plague                       Jane Romero
# 10                             NaN                      Ash Williams
# 11                      Ghost Face                               NaN
# 12                      Demogorgon  Steve Harrington & Nancy Wheeler
# 13                         The Oni                        Yui Kimura
# 14                The Deathslinger                     Zarina Kassir
# 15  Pyramid Head (The Executioner)                      Cheryl Mason
# 16                      The Blight                     Felix Richter
# 17                       The Twins                     Elodie Rakoto
# 18                   The Trickster                       Yun-Jin Lee
# 19                         Nemesis  Jill Valentine & Leon S. Kennedy
# 20          Pinhead (The Cenobite)                               NaN
# 21                             NaN                      Mikaela Reid
# 22                      The Artist                     Jonah Vasquez
# 23              Sadako (The Onryo)                    Yoichi Asakawa
# 24                      The Dredge                       Haddie Kaur
# 25  Albert Wesker (The Mastermind)       Ada Wong & Rebecca Chambers
# 26                      The Knight                  Vittorio Toscano
# 27              The Skull Merchant        Thalita Lyra & Renato Lyra
# 28                 The Singularity                      Gabriel Soma
# 29                             NaN                     Nicholas Cage
# 30                       Xenomorph                      Ellen Ripley
#
#     Reception (%)                        Notable Comments (Positive)  \
# 0              90  Unique music pays homage to source material we...
# 1              79  Unique Killer playstyle. Cool looking Survivor...
# 2              92  Fun Killer that is great for beginners. Great ...
# 3              84  Amazing perks, especially Barbeque and Chili. ...
# 4              64  Great Killer for beginners. Great for fans of ...
# 5              78  Interesting Killer gameplay. Great for fans of...
# 6              86  Great Killer perks. Good beginner Killer. Good...
# 7              84  Decent to good Killer perks. Great Killer, esp...
# 8              68                    Great perks for Survivor. Music
# 9              80  Fun Killer playstyle. Killer perks are great f...
# 10             79  Voice acting by Bruce Campbell. Perks have pot...
# 11             86                  Fun mechanics and great equipment
# 12             93  Killer is tricky, but rewarding. Loved by fans...
# 13             80  Visually impressive characters. Killer is fun ...
# 14             74  Fun ranged Killer playstyle that discourages t...
# 15             88  Interesting Killer. Konami Code easter egg. Gr...
# 16             78  Fun Killer gameplay. Perks are decent at worst...
# 17             48        Unique Killer playstyle. Fun Survivor perks
# 18             61  Killer visually stands out in the best way. In...
# 19             82  Fun Killer gameplay. Great perks. Highly recom...
# 20             40  Interesting mechanics. Voice acting does not d...
# 21             69  Good lore. Good perks, particularly Circle of ...
# 22             80   Killer design and perks are amazing. Great lore.
# 23             75  Great Killer perks. Interesting lore. Amazing ...
# 24             86  Fun Killer playstyle. Killer has an interestin...
# 25             84    Voice acting. Good Killer gameplay. Great perks
# 26             42  Good perks. Fun and versatile Killer. Great co...
# 27             35           Fun Killer gameplay. Good Survivor perks
# 28             58  Interesting lore. Consistently good Killer per...
# 29             92                            Voice acting. Fun perks
# 30             63  Interesting Killer playstyle. Great perks for ...
#
#                           Notable Comments (Negative)  \
# 0   Killer is difficult and awkward to use and rel...
# 1   Luck-based Survivor perks. Killer power is eas...
# 2               Killer is not interesting in practice
# 3   No versatility. Campy and unoriginal playstyle...
# 4   Survivor perks range from situational to bad. ...
# 5   Lack of unique music. Buggy and ruined by core...
# 6   Killer is poorly executed. Bad music. Worse ve...
# 7   Survivor perks are better in concept than exec...
# 8     Boring Killer mechanics. Misleading advertising
# 9                      Useless Survivor perks. Boring
# 10  Loud, making this the only Survivor with a dis...
# 11  Annoying to face. Bad perks with the exception...
# 12             Survivor perks are situational to weak
# 13               Clunky and confusing Killer gameplay
# 14               Killer perks are situational at best
# 15                             Boring Killer gameplay
# 16                                    Buggy collision
# 17               Buggy. Perks are situational at best
# 18  Killer is outclassed by free content, boring t...
# 19                                            Zombies
# 20  Inconvenient perks. Boring gameplay. Voice lin...
# 21  Horribly unbalanced. Overpriced. Perks encoura...
# 22  Perks for Survivor are mediocre at best. Kille...
# 23  Bad Survivor perks and skin. Underwhelming Kil...
# 24             Forgetable perks. Killer is unreliable
# 25                                              Buggy
# 26  Killer is overpowered and campy. Unbalanced ov...
# 27     Killer is unbalanced and boring. No good perks
# 28  Campy Killer gameplay. Boring and unbalanced. ...
# 29  Overpriced ($9.99 compared to $4.99 for other ...
# 30  Too expensive ($11.99 compared to $6.99 for pa...
#
#                                                 Notes
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Most reviews revolve around either promoting B...
# 4                                                 NaN
# 5         Comments are littered with 'Boop the Snoot'
# 6                                                 NaN
# 7                                                 NaN
# 8   A good chunk of reviews are spouting memes abo...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  Most comments are about how this pack was take...
# 13  Most negative comments involve the Killer bein...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Many reviews claim to buy this only for Leon K...
# 20  Killer only. Most comments involve the controv...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN

# %% [markdown]
# In order to analyze the data, I will be using a combination of boxplots and scatterplots based on the licensed and character criteria and a histogram for the reception. Once done, I will compare the averages in order to determine the effect each category has on the reception to the DLC.

# %% [markdown]
# ANALYSIS
#
#
# Based on the reviews for each DLC chapter on Steam, there is no one aspect about any given chapter that makes a DLC pack more popular than others based on game design. However, there are some aspects that are consistently tied to positive feedback, such as the presence of music and voice acting, interesting lore regarding the characters made for the game, and, in the case of licensed material, faithfulness to the source material

# %%
fig1, ax1 = plt.subplots(1, 2)
yes = ces[ces['Licensed?'] == 'Yes']['Reception (%)']
no = ces[ces['Licensed?'] == 'No']['Reception (%)']
license = [1] * len(yes)
origin = [1] * len(no)
y_x_jitter = np.random.uniform(-.1, .1, len(license))
n_x_jitter = np.random.uniform(-.1, .1, len(origin))
ax1[0].boxplot(yes)
ax1[1].boxplot(no)
ax1[0].scatter(license + y_x_jitter, yes, alpha = .5)
ax1[1].scatter(origin + n_x_jitter, no, alpha = .5)
plt.show()

# %% [markdown]
# According to the above plots, licensed DLC are generally considered better on average than non-licensed DLC, but non-licensed has a higher average of quality.

# %%
fig2, ax2 = plt.subplots()
ax2.scatter(x = ces['Reception (%)'], y = ces['Characters'])
plt.show()

# %% [markdown]
# The scatterplot above shows that the amount of characters has no effect on how well a DLC pack is recieved.

# %%
dlc = pd.read_csv(r'C:\Users\sonik\Downloads\popularity.csv')

# %%
dlc
# Out:
#     Ranking                   Pack name  Reception (%)
# 0         1            Stranger Things*             93
# 1         2            Spark of Madness             92
# 2         3               Nicolas Cage*             92
# 3         4                  Halloween*             90
# 4         5                Silent Hill*             88
# 5         6                Curtain Call             86
# 6         7                 Ghost Face*             86
# 7         8              Roots of Dread             86
# 8         9                Leatherface*             84
# 9        10         Shattered Bloodline             84
# 10       11   Resident Evil: PROJECT W*             84
# 11       12              Resident Evil*             82
# 12       13      Demise of the Faithful             80
# 13       14               Cursed Legacy             80
# 14       15        Portrait of a Murder             80
# 15       16            Of Flesh and Mud             79
# 16       17           Ash vs Evil Dead*             79
# 17       18                        Saw*             78
# 18       19              Descend Beyond             78
# 19       20              Sadako Rising*             75
# 20       21              Chains of Hate             74
# 21       22           Hour of the Witch             69
# 22       23           Darkness Among Us             68
# 23       24  A Nightmare on Elm Street*             64
# 24       25                      Alien*             63
# 25       26                    All-Kill             61
# 26       27            End Transmission             58
# 27       28            A Binding of Kin             48
# 28       29               Forged in Fog             42
# 29       30                 Hellraiser*             40
# 30       31            Tools of Torment             35

# %% [markdown]
# Asterisks indicate licensed properties
#
# Based on this chart, 7 of the top 10 DLC packs were licensed packs, meaning that licensed properties generally sell DLC. packs better than original concepts.
#
#
# Observations:
#
#  - Licensed packs are usually recommended for fans of the source material, with the exceptions of Hellraiser and Ghost Face.
#  - Art direction can usually sway opinions, as shown by Portrai of a Murder and Cursed Legacy's rankings
#  - Killers generally impact opinions more than Survivors, with the exceptions of Darkness Among Us and, to a lesser extent, the original Resident Evil pack
#  - Lore can boost opinion slightly, but it needs other factors to sell the pack
